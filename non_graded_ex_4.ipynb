# %% [markdown]
# Write a simple program for a card Role-Playing Game. Try to use only the concepts you have learned so far in the lectures.
#
# REQUIREMENTS:
#
# 1. Following are the different cards, with their characteristics, available to the player
#
# Name: Diablo
# Health: 100
# Attack: 90
# Defense: 60
#
# Name: Medusa
# Health: 100
# Attack: 70
# Defense: 70
#
# Name: Jester
# Health: 120
# Attack: 60
# Defense: 90
#
# Name: Troll
# Health: 150
# Attack: 40
# Defense: 94
#
# Name: Specter
# Health: 100
# Attack: 70
# Defense: 70
#
# Name: Mist
# Health: 100
# Attack: 75
# Defense: 65
#
# Name: Savage
# Health: 100
# Attack: 90
# Defense: 50
#
# Name: Marauder
# Health: 100
# Attack: 85
# Defense: 50
#
# Name: Wimp
# Health: 110
# Attack: 40
# Defense: 85
#
# Name: Sorcerer
# Health: 100
# Attack: 70
# Defense: 55
#
# 2. Store the above card details using a suitable data structure like list, tuple, dictionary, or any combination of these
# 3. From these cards, assign a random deck of 5 cards to both the player and the computer (opponent).
#     3.1. This should happen whenever a new game begins
# 4. Keep the game running for as long as there are cards in the player's deck or for as long as there are cards in the opponent's deck
#     4.1. Show all the cards that the player has in their deck
#     4.2. Assign a random card to the opponent, and show that to the player, along with the details of that card. Only the details of this random card must be shown.
#     4.3. Ask the player to pick a card from their own deck to fight the opponent's card.
#     4.4. If the attack value of the player's card is more than the health of opponent's card, then the player wins this round.
#     4.5. Otherwise, the player's card will fight with the opponent's card.
#         4.5.1. Calculate the damage the player's card does to the opponent's card. This calculation should take care of the fact that the opponent's card will first defend the attack using its 'Defense' value. And if there is no defense value, only then will the player's attack value will affect the opponent card's health.
#
#         e.g.,
#         Player card
#
#         Name: Wimp
#         Health: 110
#         Attack: 40
#         Defense: 85
#
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 100
#         Attack: 70
#         Defense: 55
#
#         If the Wimp attacks Sorcerer, first, it will only affect Sorcerer's 'Defense' value. Sorcerer's defense value will decrease by the the attack value of player's Wimp card. Therefore, after the attack, the defense value will change from 55 to 15, as 55 - 40 = 15. Therefore,
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 100
#         Attack: 70
#         Defense: 15
#
#         Now, if in the next round, Wimp attacks Sorcerer again, then Sorcerer's defense value will decrease to 0, but its health will also be affected. The health will be affected by 25 points, as 40 - 15 = 25. So, Sorcerer's health will now decrease from 100 to 75
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 75
#         Attack: 70
#         Defense: 0
#
#         Now, let's say in a later round, the player uses the Marauder card, which has an attack value of 85, and the computer is using Sorcerer, whose health value is 75.
#
#         In that case, Sorcerer will be defeated, as 85 > 75. When this happens, remove the Sorcerer card from the deck of the opponent.
#
#         Display properly all these changes to the player at every round, so that they know how their attacks affected the round and what they can do next.
#
#         DO NOT just show the card details. Write proper statements, describing the process, as you may have seen in the demonstration given by the teacher
#
#         4.5.2. After the user's turn, make sure all the card values adjusted accordingly, just as described above.
#         4.5.3. ONLY a card's 'Defense' and 'Health' value changes after an attack. And once the 'Health' value of a card reaches 0 or drops below it, that card MUST be removed from the deck.
#         4.5.4. After the player's turn, pause the second for some seconds, e.g., time.sleep(3) will pause the game for 3 seconds.
#     4.6. Display that now it's the opponent's turn.
#     4.7. Make sure there are cards available in opponent's deck. If there aren't, then the game ends and the player wins.
#     4.8. If there are still cards available in opponent's deck, draw a random card from the opponent's deck, and display its details to the player.
#     4.9. Then display the cards available in the player's deck.
#     4.10 Ask the user to pick one card from their own deck to fight the opponent's card.
#     4.11. REPEAT THE SAME LOGIC AS STATED FROM POINT 4.4 TO 4.5.3. But this time, from the perspective of the opponent.
#     4.12. After the opponent's turn is over, display that a new round will begin in some seconds.
# 5. If it's found that the opponent has no card in their deck, then display a message stating player is the winner, otherwise display that the opponent won.

# %%
import random
import time

card_deck = [
    {"name": "Diablo", "health": 100, "attack": 90, "defense": 60},
    {"name": "Medusa", "health": 100, "attack": 70, "defense": 70},
    {"name": "Jester", "health": 120, "attack": 60, "defense": 90},
    {"name": "Troll", "health": 150, "attack": 40, "defense": 94},
    {"name": "Specter", "health": 100, "attack": 70, "defense": 70},
    {"name": "Mist", "health": 100, "attack": 75, "defense": 65},
    {"name": "Savage", "health": 100, "attack": 90, "defense": 50},
    {"name": "Marauder", "health": 100, "attack": 85, "defense": 50},
    {"name": "Wimp", "health": 110, "attack": 40, "defense": 85},
    {"name": "Sorcerer", "health": 100, "attack": 70, "defense": 55}
]

def print_card(card):
    print(f'''  Name: {card['name']}, 
        Health: {card['health']}, 
        Attack: {card['attack']}, 
        Defense: {card['defense']}''')

def deal_cards(deck, deck_size):
    return random.sample(deck, deck_size)

def print_deck(deck):
    for i, card in enumerate(deck):
        print(f"{i}: {card['name']}")

def attack(player_card, opponent_card):
    damage = player_card['attack'] - opponent_card['defense']
    damage = max(damage, 0)  
    opponent_card['health'] -= damage
    if opponent_card['health'] <= 0:
        print(f"{opponent_card['name']} has been defeated!")
        return True
    else:
        print(f"{opponent_card['name']} now has {opponent_card['health']} health left.")
        return False

def get_choice(deck):
    choice_index = int(input(f"Choose your card (0-{len(deck)-1}): "))
    while choice_index < 0 or choice_index >= len(deck):
        print("Invalid choice, please try again.")
        choice_index = int(input(f"Choose your card (0-{len(deck)-1}): "))
    return choice_index

player_deck = deal_cards(card_deck, 5)
opponent_deck = deal_cards(card_deck, 5)

while player_deck and opponent_deck:
    print("\nPlayer's Turn")
    print("Your cards you have:")
    for i, card in enumerate(player_deck):
        print(f"NO: {i}" , end=" ")
        print_card(card)
    opponent_card = random.choice(opponent_deck)
    print("The computer's card:")
    print_card(opponent_card)
    choice_index = get_choice(player_deck)
    player_card = player_deck[choice_index]
    print("\nYour card:")
    print_card(player_card)

    if attack(player_card, opponent_card):
        opponent_deck.remove(opponent_card)

    time.sleep(3)  

    if not opponent_deck:
        print("\nComputer's deck is empty. Player wins!")
        break

    print("\nOpponent's Turn")

    opponent_choice_index = random.randint(0, len(opponent_deck) - 1)
    opponent_card = opponent_deck[opponent_choice_index]
    player_card = player_deck[choice_index]
    print("\nThe computer chooses to attack with:")
    print_card(opponent_card)

    if attack(opponent_card, player_card):
        player_deck.remove(player_card)

    time.sleep(3)  
    if not player_deck:
        print("\nPlayer's deck is empty. Computer wins!")
        break

if not player_deck:
    print("Computer wins!")
elif not opponent_deck:
    print("Player wins!")
# Out:
# Player's Turn
# Your cards you have:
# NO: 0   Name: Jester,
#         Health: 120,
#         Attack: 60,
#         Defense: 90
# NO: 1   Name: Medusa,
#         Health: 100,
#         Attack: 70,
#         Defense: 70
# NO: 2   Name: Diablo,
#         Health: 100,
#         Attack: 90,
#         Defense: 60
# NO: 3   Name: Marauder,
#         Health: 100,
#         Attack: 85,
#         Defense: 50
# NO: 4   Name: Troll,
#         Health: 150,
#         Attack: 40,
#         Defense: 94
# The computer's card:
#   Name: Troll,
#         Health: 150,
#         Attack: 40,
#         Defense: 94
#
# Your card:
#   Name: Marauder,
#         Health: 100,
#         Attack: 85,
#         Defense: 50
# Troll now has 150 health left.
#
# Opponent's Turn
#
# The computer chooses to attack with:
#   Name: Troll,
#         Health: 150,
#         Attack: 40,
#         Defense: 94
# Marauder now has 100 health left.
#
# Player's Turn
# Your cards you have:
# NO: 0   Name: Jester,
#         Health: 120,
#         Attack: 60,
#         Defense: 90
# NO: 1   Name: Medusa,
#         Health: 100,
#         Attack: 70,
#         Defense: 70
# NO: 2   Name: Diablo,
#         Health: 100,
#         Attack: 90,
#         Defense: 60
# NO: 3   Name: Marauder,
#         Health: 100,
#         Attack: 85,
#         Defense: 50
# NO: 4   Name: Troll,
#         Health: 150,
#         Attack: 40,
#         Defense: 94
# The computer's card:
#   Name: Specter,
#         Health: 100,
#         Attack: 70,
#         Defense: 70
#
# Your card:
#   Name: Diablo,
#         Health: 100,
#         Attack: 90,
#         Defense: 60
# Specter now has 80 health left.
#
# Opponent's Turn
#
# The computer chooses to attack with:
#   Name: Troll,
#         Health: 150,
#         Attack: 40,
#         Defense: 94
# Diablo now has 100 health left.
#
# Player's Turn
# Your cards you have:
# NO: 0   Name: Jester,
#         Health: 120,
#         Attack: 60,
#         Defense: 90
# NO: 1   Name: Medusa,
#         Health: 100,
#         Attack: 70,
#         Defense: 70
# NO: 2   Name: Diablo,
#         Health: 100,
#         Attack: 90,
#         Defense: 60
# NO: 3   Name: Marauder,
#         Health: 100,
#         Attack: 85,
#         Defense: 50
# NO: 4   Name: Troll,
#         Health: 150,
#         Attack: 40,
#         Defense: 94
# The computer's card:
#   Name: Wimp,
#         Health: 110,
#         Attack: 40,
#         Defense: 85
#
# Your card:
#   Name: Diablo,
#         Health: 100,
#         Attack: 90,
#         Defense: 60
# Wimp now has 105 health left.
#
# Opponent's Turn
#
# The computer chooses to attack with:
#   Name: Diablo,
#         Health: 100,
#         Attack: 90,
#         Defense: 60
# Diablo now has 70 health left.
#
# Player's Turn
# Your cards you have:
# NO: 0   Name: Jester,
#         Health: 120,
#         Attack: 60,
#         Defense: 90
# NO: 1   Name: Medusa,
#         Health: 100,
#         Attack: 70,
#         Defense: 70
# NO: 2   Name: Diablo,
#         Health: 70,
#         Attack: 90,
#         Defense: 60
# NO: 3   Name: Marauder,
#         Health: 100,
#         Attack: 85,
#         Defense: 50
# NO: 4   Name: Troll,
#         Health: 150,
#         Attack: 40,
#         Defense: 94
# The computer's card:
#   Name: Troll,
#         Health: 150,
#         Attack: 40,
#         Defense: 94
#
# Your card:
#   Name: Diablo,
#         Health: 70,
#         Attack: 90,
#         Defense: 60
# Troll now has 150 health left.
#
# Opponent's Turn
#
# The computer chooses to attack with:
#   Name: Troll,
#         Health: 150,
#         Attack: 40,
#         Defense: 94
# Diablo now has 70 health left.
#
# Player's Turn
# Your cards you have:
# NO: 0   Name: Jester,
#         Health: 120,
#         Attack: 60,
#         Defense: 90
# NO: 1   Name: Medusa,
#         Health: 100,
#         Attack: 70,
#         Defense: 70
# NO: 2   Name: Diablo,
#         Health: 70,
#         Attack: 90,
#         Defense: 60
# NO: 3   Name: Marauder,
#         Health: 100,
#         Attack: 85,
#         Defense: 50
# NO: 4   Name: Troll,
#         Health: 150,
#         Attack: 40,
#         Defense: 94
# The computer's card:
#   Name: Marauder,
#         Health: 100,
#         Attack: 85,
#         Defense: 50
#
# Your card:
#   Name: Diablo,
#         Health: 70,
#         Attack: 90,
#         Defense: 60
# Marauder now has 60 health left.
#
# Opponent's Turn
#
# The computer chooses to attack with:
#   Name: Troll,
#         Health: 150,
#         Attack: 40,
#         Defense: 94
# Diablo now has 70 health left.
#
# Player's Turn
# Your cards you have:
# NO: 0   Name: Jester,
#         Health: 120,
#         Attack: 60,
#         Defense: 90
# NO: 1   Name: Medusa,
#         Health: 100,
#         Attack: 70,
#         Defense: 70
# NO: 2   Name: Diablo,
#         Health: 70,
#         Attack: 90,
#         Defense: 60
# NO: 3   Name: Marauder,
#         Health: 60,
#         Attack: 85,
#         Defense: 50
# NO: 4   Name: Troll,
#         Health: 150,
#         Attack: 40,
#         Defense: 94
# The computer's card:
#   Name: Diablo,
#         Health: 70,
#         Attack: 90,
#         Defense: 60
#
# Your card:
#   Name: Diablo,
#         Health: 70,
#         Attack: 90,
#         Defense: 60
# Diablo now has 40 health left.
#
# Opponent's Turn
#
# The computer chooses to attack with:
#   Name: Marauder,
#         Health: 60,
#         Attack: 85,
#         Defense: 50
# Diablo now has 15 health left.
#
# Player's Turn
# Your cards you have:
# NO: 0   Name: Jester,
#         Health: 120,
#         Attack: 60,
#         Defense: 90
# NO: 1   Name: Medusa,
#         Health: 100,
#         Attack: 70,
#         Defense: 70
# NO: 2   Name: Diablo,
#         Health: 15,
#         Attack: 90,
#         Defense: 60
# NO: 3   Name: Marauder,
#         Health: 60,
#         Attack: 85,
#         Defense: 50
# NO: 4   Name: Troll,
#         Health: 150,
#         Attack: 40,
#         Defense: 94
# The computer's card:
#   Name: Troll,
#         Health: 150,
#         Attack: 40,
#         Defense: 94
#
# Your card:
#   Name: Diablo,
#         Health: 15,
#         Attack: 90,
#         Defense: 60
# Troll now has 150 health left.
#
# Opponent's Turn
#
# The computer chooses to attack with:
#   Name: Specter,
#         Health: 80,
#         Attack: 70,
#         Defense: 70
# Diablo now has 5 health left.
#
# Player's Turn
# Your cards you have:
# NO: 0   Name: Jester,
#         Health: 120,
#         Attack: 60,
#         Defense: 90
# NO: 1   Name: Medusa,
#         Health: 100,
#         Attack: 70,
#         Defense: 70
# NO: 2   Name: Diablo,
#         Health: 5,
#         Attack: 90,
#         Defense: 60
# NO: 3   Name: Marauder,
#         Health: 60,
#         Attack: 85,
#         Defense: 50
# NO: 4   Name: Troll,
#         Health: 150,
#         Attack: 40,
#         Defense: 94
# The computer's card:
#   Name: Wimp,
#         Health: 105,
#         Attack: 40,
#         Defense: 85
